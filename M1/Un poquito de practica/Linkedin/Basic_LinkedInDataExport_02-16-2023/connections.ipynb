# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv(r'Connections.csv', on_bad_lines= 'skip')
# aca tuve que poner el on_bad_lines xq mi archivo tiene un par de lineas vacias
df.head()
# Out:
#                                               Notes:
# 0  When exporting your connection data, you may n...

# %%
df = pd.read_csv(r'Connections.csv', skiprows=2)
df
# Out:
#            First Name          Last Name Email Address  \
# 0             Leandro              López           NaN
# 1            Victoria        Cascallares           NaN
# 2              Vanesa               Mena           NaN
# 3          Jose Maria             Iturbe           NaN
# 4              Matias              Godoy           NaN
# ...               ...                ...           ...
# 1646     Juan Facundo            Quallio           NaN
# 1647          Leandro  Marcangelo Ramini           NaN
# 1648  Gianni Humberto           Sparvoli           NaN
# 1649           German        Gozdziewski           NaN
# 1650           Romina              Sejas           NaN
#
#                                Company                              Position  \
# 0                            C.I.B.S.A                 Delineante de AutoCAD
# 1                             aliantec                         IT Recruiter
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1651 entries, 0 to 1650
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   First Name     1648 non-null   object
#  1   Last Name      1648 non-null   object
#  2   Email Address  44 non-null     object
#  3   Company        1630 non-null   object
#  4   Position       1632 non-null   object
#  5   Connected On   1651 non-null   object
# dtypes: object(6)
# memory usage: 77.5+ KB

# %%
df.drop(columns=['Email Address'], inplace=True)
df.dropna(inplace=True,)
df
# Out:
#            First Name          Last Name                           Company  \
# 0             Leandro              López                         C.I.B.S.A
# 1            Victoria        Cascallares                          aliantec
# 2              Vanesa               Mena                    Practia Global
# 3          Jose Maria             Iturbe            Entre Rios Crushing SA
# 4              Matias              Godoy                        KUNAN S.A.
# ...               ...                ...                               ...
# 1646     Juan Facundo            Quallio                   UTN San Nicolás
# 1647          Leandro  Marcangelo Ramini  Universidad Tecnologica Nacional
# 1648  Gianni Humberto           Sparvoli                         EEST N° 6
# 1649           German        Gozdziewski                          UTN frsn
# 1650           Romina              Sejas                       Plantium SA
#
#                                   Position Connected On
# ...

# %%
df.reset_index(inplace = True , drop=True)
df
# Out:
#            First Name          Last Name                           Company  \
# 0             Leandro              López                         C.I.B.S.A
# 1            Victoria        Cascallares                          aliantec
# 2              Vanesa               Mena                    Practia Global
# 3          Jose Maria             Iturbe            Entre Rios Crushing SA
# 4              Matias              Godoy                        KUNAN S.A.
# ...               ...                ...                               ...
# 1625     Juan Facundo            Quallio                   UTN San Nicolás
# 1626          Leandro  Marcangelo Ramini  Universidad Tecnologica Nacional
# 1627  Gianni Humberto           Sparvoli                         EEST N° 6
# 1628           German        Gozdziewski                          UTN frsn
# 1629           Romina              Sejas                       Plantium SA
#
#                                   Position Connected On
# ...

# %%
company_counts = pd.DataFrame(df['Company'].value_counts())

# %%
df['Connected On'] = pd.to_datetime(df['Connected On']).dt.strftime('%Y-%m-%d')
df['Connected On']
# Out:
# C:\Users\Martin\AppData\Local\Temp\ipykernel_8292\2489051299.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Connected On'] = pd.to_datetime(df['Connected On']).dt.strftime('%Y-%m-%d')
# 0       2023-02-15
# 1       2023-02-15
# 2       2023-02-14
# 3       2023-02-14
# 4       2023-02-14
#            ...
# 1625    2018-11-16
# 1626    2018-02-11
# 1627    2018-01-11
# 1628    2018-10-29
# 1629    2018-01-05
# Name: Connected On, Length: 1630, dtype: object

# %%
df
# Out:
#       index       First Name          Last Name  \
# 0         0          Leandro              López
# 1         1         Victoria        Cascallares
# 2         2           Vanesa               Mena
# 3         3       Jose Maria             Iturbe
# 4         4           Matias              Godoy
# ...     ...              ...                ...
# 1625   1646     Juan Facundo            Quallio
# 1626   1647          Leandro  Marcangelo Ramini
# 1627   1648  Gianni Humberto           Sparvoli
# 1628   1649           German        Gozdziewski
# 1629   1650           Romina              Sejas
#
#                                Company                              Position  \
# 0                            C.I.B.S.A                 Delineante de AutoCAD
# 1                             aliantec                         IT Recruiter
# 2                       Practia Global                     Data Scientist Jr
# ...

# %% [markdown]
# # Ahora viene la parte de cargarlo a SQL y efectuar consultas
